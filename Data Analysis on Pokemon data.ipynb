# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pokemon=pd.read_csv('D:\\PGP IN DATA SCIENCE with careerera\\Files\\pokemon_data.csv')

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokemon.describe(include='O')
# Out:
#              Name Type 1  Type 2
# count         800    800     414
# unique        800     18      18
# top     Bulbasaur  Water  Flying
# freq            1    112      97

# %%
pokemon.Name.nunique()
# Out:
# 800

# %%
pokemon.rename({'Type 1':'Type_1'}, axis=1, inplace=True)

# %%
pokemon.rename({'Type 2':'Type_2'}, axis=1, inplace=True)

# %%
pokemon
# Out:
#        #                   Name   Type_1  Type_2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.Type_1.nunique()
# Out:
# 18

# %%
pokemon.Type_2.nunique()
# Out:
# 18

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type_1      800 non-null    object
#  3   Type_2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
pokemon.HP.nunique()
# Out:
# 94

# %%
pokemon.Attack.nunique()
# Out:
# 111

# %%
pokemon.rename({'Sp. Atk':'Sp_Atk','Sp. Def':'Sp_Def'},axis=1, inplace=True)

# %%
pokemon
# Out:
#        #                   Name   Type_1  Type_2  HP  Attack  Defense  Sp_Atk  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49      65
# 1      2                Ivysaur    Grass  Poison  60      62       63      80
# 2      3               Venusaur    Grass  Poison  80      82       83     100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123     122
# 4      4             Charmander     Fire     NaN  39      52       43      60
# ..   ...                    ...      ...     ...  ..     ...      ...     ...
# 795  719                Diancie     Rock   Fairy  50     100      150     100
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60     150
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60     170
# 799  721              Volcanion     Fire   Water  80     110      120     130
#
# ...

# %%
pokemon.Sp_Atk.nunique()
# Out:
# 105

# %%
pokemon.Sp_Def.nunique()
# Out:
# 92

# %%
pokemon.Speed.nunique()
# Out:
# 108

# %%
pokemon.Generation.nunique()
# Out:
# 6

# %%
pokemon.Legendary.nunique()
# Out:
# 2

# %%
pd.pivot_table(pokemon, values='Generation', index='Legendary', aggfunc=sum)
# Out:
#            Generation
# Legendary
# False            2414
# True              245

# %%
sns.countplot(x='Generation', data=pokemon);

# %%
sns.barplot(x='Type 1', y='Speed', data=pokemon);

# %%
sns.barplot(x='Type 2', y='Speed', data=pokemon);

# %%
pokemon=pd.read_csv('D:\\PGP IN DATA SCIENCE with careerera\\Files\\pokemon_data.csv')

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.set_index(['Legendary'])
# Out:
#              #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# Legendary
# False        1              Bulbasaur    Grass  Poison  45      49       49
# False        2                Ivysaur    Grass  Poison  60      62       63
# False        3               Venusaur    Grass  Poison  80      82       83
# False        3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# False        4             Charmander     Fire     NaN  39      52       43
# ...        ...                    ...      ...     ...  ..     ...      ...
# True       719                Diancie     Rock   Fairy  50     100      150
# True       719    DiancieMega Diancie     Rock   Fairy  50     160      110
# True       720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# True       720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# True       721              Volcanion     Fire   Water  80     110      120
#
# ...

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.reset_index()
# Out:
#      index    #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0        0    1              Bulbasaur    Grass  Poison  45      49       49
# 1        1    2                Ivysaur    Grass  Poison  60      62       63
# 2        2    3               Venusaur    Grass  Poison  80      82       83
# 3        3    3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4        4    4             Charmander     Fire     NaN  39      52       43
# ..     ...  ...                    ...      ...     ...  ..     ...      ...
# 795    795  719                Diancie     Rock   Fairy  50     100      150
# 796    796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797    797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798    798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799    799  721              Volcanion     Fire   Water  80     110      120
#
# ...

# %%
pokemon.drop('#',axis=1, inplace=True)

# %%
pokemon
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemon_gen_6=pokemon[pokemon['Generation']==6]

# %%
pokemon_gen_6
# Out:
#                     Name   Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# 718              Chespin    Grass       NaN  56      61       65       48
# 719            Quilladin    Grass       NaN  61      78       95       56
# 720           Chesnaught    Grass  Fighting  88     107      122       74
# 721             Fennekin     Fire       NaN  40      45       40       62
# 722              Braixen     Fire       NaN  59      59       58       90
# ..                   ...      ...       ...  ..     ...      ...      ...
# 795              Diancie     Rock     Fairy  50     100      150      100
# 796  DiancieMega Diancie     Rock     Fairy  50     160      110      160
# 797  HoopaHoopa Confined  Psychic     Ghost  80     110       60      150
# 798   HoopaHoopa Unbound  Psychic      Dark  80     160       60      170
# 799            Volcanion     Fire     Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...
